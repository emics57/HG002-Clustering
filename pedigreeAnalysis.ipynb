# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as mplpatches
import numpy as np
import argparse
import pandas as pd
import natsort

# %%
df = pd.read_csv('PAN010hap1_2.mashmap.txt', delimiter=' ', header=None, names=['contig', 'contig length', 'start', 'end', 'strand', 'chromosome', 'mapping_length', 'chrom_start', 'chrom_end', 'mapping_identity'])
df = df.iloc[natsort.index_natsorted(df['chromosome'])]
df
# Out:
#                 contig  contig length  start        end strand chromosome  \
# 11  haplotype1-0000027      240992136      0  240992135      +       chr1
# 26  haplotype1-0000011        2591396      0    2591395      +       chr1
# 22  haplotype1-0000006      111664669      0  111664668      +       chr2
# 24  haplotype1-0000009      181834292      0  181834291      +       chr2
# 31  haplotype1-0000023       59666364      0   59666363      +       chr3
# 33  haplotype1-0000028      143274763      0  143274762      +       chr3
# 27  haplotype1-0000014      192203194      0  192203193      +       chr4
# 1   haplotype1-0000003      183852570      0  183852569      +       chr5
# 29  haplotype1-0000017      163495770      0  163495769      +       chr6
# 38  haplotype1-0000035        8720607      0    8720606      +       chr6
# 7   haplotype1-0000020        1015399      0    1015398      +       chr7
# 28  haplotype1-0000016      159236327      0  159236326      +       chr7
# ...
